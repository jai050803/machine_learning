# %% [markdown]
# # Polynomial Regression

# %%
#importing the libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Position_Salaries.csv')

X = df.iloc[:, 1:2].values
y = df.iloc[:, -1].values

# %% [markdown]
# 1. we don't need to split the data into training and the testing set.
# we also need not to apply the feature scaling to the data

# %% [markdown]
# #### Fitting the linear regression to the dataset

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y , color="hotpink", marker= "+")
plt.plot(X, regressor.predict(X), color="blue")
plt.title("Truth or Bluff (Linear Regression)")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# #### Fitting the polynomial regression to the dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
X_poly
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])

# %%
# fit this X_poly with linear regression

lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
#visualize the result of the polynomial regression
plt.scatter(X, y , color="hotpink", marker= "+")
plt.plot(X, lin_reg2.predict(X_poly), color="blue")
plt.title("Truth or Bluff (Polynomial Regression)")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %%
# a better graph

X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X, y , color="hotpink", marker= "+")
plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)), color="blue")
plt.title("Truth or Bluff (Polynomial Regression)")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()
# Out:
# C:\Users\sjai5\AppData\Local\Temp\ipykernel_17492\3355819159.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %%
# predicting a new result with linear regression
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
#predicting the new result with polynomial regression
lin_reg2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265158])
