# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ##### Apply basic data preprocessing technique on the data

# %%
# Importing the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# import the dataset and divide it into training and testing set

# %%
df = pd.read_csv('50_Startups.csv')
df.dropna()
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# splitting the dataset into independent and dependent features
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
# encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

label_encoder = LabelEncoder()
X[:, 3] = label_encoder.fit_transform(X[:, 3])
# onehotencoder = OneHotEncoder(categorical_features = [3])
# X = onehotencoder.fit_transform(X).toarray()
onehotencoder = OneHotEncoder()
# Apply one-hot encoding using ColumnTransformer
ct = ColumnTransformer(
    transformers=[('encoder', onehotencoder, [3])],  # Apply one-hot encoding to the 4th column
    remainder='passthrough'  # Keep the other columns unchanged
)
X = ct.fit_transform(X)

# %%
X = X[:,1:] #avoiding the dummy variable trap

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# #### Fitting the multiple linear regression to the training set

# %%
# fitting multiple linear regression into the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Predicting the test set results

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([103015.20159795, 132582.27760816, 132447.73845175,  71976.09851258,
#        178537.48221056, 116161.24230165,  67851.69209676,  98791.73374687,
#        113969.43533013, 167921.06569552])

# %% [markdown]
# #### Building the optimal model using the Backward elimination
#
# In our model, we will identify the variables which are not having great impact on the output. There are some variables that are highly statistically significant and some are not. So if we remove those independent variables then we get more optimal model.
#
# We will identify the independent variables which have have great impact on the dependent variable profit. This effect can be positive (decrease in profit) or can be positive(increase in profit).

# %%
#preparation for the backward elimination

#we need the stats model library for this
import statsmodels.formula.api as sm

#adding a column of 1s in our matrix of features

X = np.append(arr= np.ones((50,1)).astype(float), values = X, axis = 1)

# %% [markdown]
# ### Backward Elimination

# %% [markdown]
# 1. select a significant level.. let it be 0.05
#
# 2. create a new matrix of features which contains all the columns index (original matrix of features)

# %%
x_opt = X[:, [0,1,2,3,4,5]]

# %% [markdown]
# 3. Fit the full model to all the possible predictors

# %%
"""
import statsmodels.api as sm
x_opt = X[:, [0,1,2,3,4,5]]
regressor_ols = sm.OLS(endog= y, exog = X).fit()
regressor_ols.summary()

check for highest p value and remove if it is greater that significant level
x_opt = X[:, [0,1,2,3,5]]
regressor_ols = sm.OLS(endog= y, exog = X).fit()
regressor_ols.summary()

again check for highest p value and remove if it is greater that significant level
x_opt = X[:, [0,1,3,5]]
regressor_ols = sm.OLS(endog= y, exog = X).fit()
regressor_ols.summary()

again check for highest p value and remove if it is greater that significant level
x_opt = X[:, [0,1,5]]
regressor_ols = sm.OLS(endog= y, exog = X).fit()
regressor_ols.summary()

again check for highest p value and remove if it is greater that significant level
x_opt = X[:, [0,1]]
regressor_ols = sm.OLS(endog= y, exog = X).fit()
regressor_ols.summary()

"""
# Out:
# '\nimport statsmodels.api as sm\nx_opt = X[:, [0,1,2,3,4,5]]\nregressor_ols = sm.OLS(endog= y, exog = X).fit()\nregressor_ols.summary()\n\ncheck for highest p value and remove if it is greater that significant level\nx_opt = X[:, [0,1,2,3,5]]\nregressor_ols = sm.OLS(endog= y, exog = X).fit()\nregressor_ols.summary()\n\nagain check for highest p value and remove if it is greater that significant level\nx_opt = X[:, [0,1,3,5]]\nregressor_ols = sm.OLS(endog= y, exog = X).fit()\nregressor_ols.summary()\n\nagain check for highest p value and remove if it is greater that significant level\nx_opt = X[:, [0,1,5]]\nregressor_ols = sm.OLS(endog= y, exog = X).fit()\nregressor_ols.summary()\n\nagain check for highest p value and remove if it is greater that significant level\nx_opt = X[:, [0,1]]\nregressor_ols = sm.OLS(endog= y, exog = X).fit()\nregressor_ols.summary()\n\n'
