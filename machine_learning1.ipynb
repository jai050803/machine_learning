# %% [markdown]
# ## Machine Learning Day 1 - Introduction

# %% [markdown]
# #### what is machine learning?

# %% [markdown]
# Machine learning is programming computers to optimize a performance criterion using example
# data or past experience. We have a model defined up to some parameters, and learning is the
# execution of a computer program to optimize the parameters of the model using the training data or
# past experience. The model may be predictive to make predictions in the future, or descriptive to gain
# knowledge from data, or both.

# %% [markdown]
# ## Data Types
#
# 1. Numerical data - data which are in form of numbers. it have two categories -
#         a. Discrete Data - Limited to integers
#         b. Continous Data - can be any number
#
# 2. Categorial Data - Values that cannot be measured up against each other
#
# 3. Ordinal data - just like categorial data but can be measured up against each other

# %% [markdown]
# ## Types of Machine Learning
#
# 1. Supervised Learning
# 2. Unsupervised Learning
# 3. Reinforcement learning

# %% [markdown]
# ## Steps in machine learning
#
# 1. Understand the problem
# 2. Data collection from sources
# 3. Data preparation
# 4. Data exploration and wrangling
# 5. data modeling
# 6. Model training
# 7. Model Testing or verification
# 8. Model Deployment

# %% [markdown]
# ### Supervised Learning
#
# The goal is to map the input variable x with the output variable y

# %% [markdown]
# #### Steps of supervised learning

# %% [markdown]
# 1. labelled dataset
# 2. Model Training
# 3. Predictions
# 4. Output

# %% [markdown]
# ### Types of Supervised Machine learning algorithms
#
#     1. Regression
#     2. Classification

# %% [markdown]
# #### Regression
# In regression, We take the numeric data. It is used when the independent and the dependent variables have some relation between them.
#
# Data taken is continous like data of weight where weights don't have much difference or the data of the market, etc.
#
# ##### Some common regression algorithms used are
#
# 1. Linear Regression
# 2. Polynomial regression
# 3. Regression Trees

# %% [markdown]
# ### Classification
#
# It is used on the categorial data. Categorial data are those which have 2 logics like yes/no or true/false or right/wrong or day/night etc. These are called binary classification and if we have multiple output values then we call it multiple classification.
#
# ##### Some common classification techniques are
#
# 1. Random Forest
# 2. Decision Trees
# 3. Logistic Regression
# 4. Support Vector machines

# %% [markdown]
# ## Advantages of Supervised Machine Learning
#
# 1. You have full control over what the machine is learning
# 2. You can easily test and debug your model
# 3. You can determine the number of classes

# %% [markdown]
# ## disadvantages of Supervised machine learning
#
# 1. Limited scope
# 2. Collecting labelled data is time consuming
# 3. Wrong prediction

# %% [markdown]
# ## Regression

# %% [markdown]
# The term regression is used when you try to find the relationship between variables.
#
# Types of Regression -
#
# 1. Linear Regression
# 2. Polynomial Regression
# 3. Multiple Regression

# %% [markdown]
# ## Linear Regression
#
# Draw a straight line beween the data points using the relationship. This line can be used to predict the future values

# %% [markdown]
# #### How does it work
#
# 1. Draw a scatter plot between the data
#
# 2. Import scipy and draw the line of linear regression between them

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))
plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %%
print(round(r,2))
print(round(p,2))
print(round(std_err,2))
# Out:
# -0.76
# 0.0
# 0.45

# %% [markdown]
# The equation for the line is y*x + b where b is the intercept.

# %% [markdown]
# ## R is for relationship
#
# If there is no relationship then the linear regression model cannot predict anything
#
# the value of r ranges from -1 to 1 where 0 means no relationship and 1 and -1 means 100% related
#
# In above data - the relationship r is 76%, not perfect but can be used for linear regression.
#
# now we can use this data to predict the future values

# %%
speed = myfunc(10)
print(round(speed,2)) # give the speed for a 10 year old car
# Out:
# 85.59

# %% [markdown]
# ## Bad Fit and Good Fit
#
# bad fit is the data where the linear regression model is not the perfect fit to predict the future values

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
print(round(r,3))
# Out:
# 0.013

# %% [markdown]
# as the relationship is just 0.013 which means a very bad relationship and hence we cannot predict the outcomes with the values and hence not suitable for the linear regression model

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# If your data points clearly will not fit a linear regression (a straight line through all data points), it might be ideal for polynomial regression.
#
# Polynomial regression, like linear regression, uses the relationship between the variables x and y to find the best way to draw a line through the data points.

# %% [markdown]
# ### Steps to perform polynomial regression
#
# 1. import the required modules
# 2. Create the arrays for x and y values
# 3. numpy has a method to make a polynomial model
# 4. specify how the line will display. starting and ending position
# 5. Draw the original scatter plot
# 6. Draw the line of polynomial regression

# %%
x_poly = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y_poly= [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# %%
mymodel = np.poly1d(np.polyfit(x_poly, y_poly, 3))
myline = np.linspace(1, 22, 100)
plt.scatter(x_poly, y_poly)
plt.plot(myline, mymodel(myline))
plt.show()
